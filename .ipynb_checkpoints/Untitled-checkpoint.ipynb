# %%
def normalize_boxes(boxes, img_shape):
    h, w = img_shape[0], img_shape[1]
    norm_boxes = []
    for xmin, ymin, xmax, ymax in boxes:
        norm_boxes.append([ymin / h, xmin / w, ymax / h, xmax / w])
    return tf.convert_to_tensor([norm_boxes], dtype=tf.float32)  # batch dimension

# %%
from src.dataset import dataset, visualize_example

# %%
import numpy as np
batch = next(iter(dataset))

images = batch["image"]
boxes_batch = batch["boxes"]
labels_batch = batch["labels"]
image = images[0].numpy()
boxes = boxes_batch[0].numpy()
labels = labels_batch[0].numpy()
print("Image shape :", image.shape)
print("Boxes shape :", boxes.shape)
print("Labels shape:", labels.shape)
print("Number of objects:", np.sum(~np.all(boxes == 0, axis=1)))
# Out:
# Image shape : (224, 224, 3)
# Boxes shape : (5, 4)
# Labels shape: (5,)
# Number of objects: 5

# %%
visualize_example(dataset)

# %%
from src.model import build_model

# %%
import tensorflow as tf

# %%
model = build_model()
model.summary()

dummy = tf.random.normal((1, 224, 224, 3))
output = model(dummy)

print(output.shape)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ sequential (Sequential)       │ (None, 224, 224, 3)       │               0 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 112, 112, 32)      │             864 │ sequential[1][0]           │
# ...

# %%
from src.dataset import build_yolo_dataset

# %%
dataset = build_yolo_dataset(batch_size=2)

batch = next(iter(dataset))

print(batch["image"].shape)
print(batch["targets"].shape)
# Out:
# (2, 224, 224, 3)
# (2, 7, 7, 2, 25)

# %%
pred = model(batch["image"])

print(pred.shape)
# Out:
# (2, 7, 7, 2, 25)

# %%
from src.loss import YOLOLoss

loss_fn = YOLOLoss(
    lambda_box=5.0,
    lambda_obj=1.0,
    lambda_noobj=0.5,
    lambda_class=1.0,
)

# %%
loss = loss_fn(batch["targets"], pred)

print(loss)
# Out:
# tf.Tensor(237.98853, shape=(), dtype=float32)

# %%
dataset = build_yolo_dataset(batch_size=2)
batch = next(iter(dataset))

images = batch["image"]
targets = batch["targets"]

with tf.GradientTape() as tape:
    pred = model(images, training=True)
    loss = loss_fn(targets, pred)

grads = tape.gradient(loss, model.trainable_variables)

print(loss)

for g in grads:
    print(g is None)
# Out:
# tf.Tensor(297.6684, shape=(), dtype=float32)
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
yolo_dataset = build_yolo_dataset()
train_dataset = yolo_dataset.map(
    lambda batch: (batch["image"], batch["targets"]),
    num_parallel_calls=tf.data.AUTOTUNE,
)

loss_fn = YOLOLoss(
    lambda_box=5.0,
    lambda_obj=1.0,
    lambda_noobj=0.5,
    lambda_class=1.0,
)

model = build_model()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=loss_fn,
)

history = model.fit(
    train_dataset,
    steps_per_epoch=3,
    epochs=3,
    verbose=1,
)

print(history.history)
# Out:
# Epoch 1/3
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - loss: 146.4393
# Epoch 2/3
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - loss: 186.2804
# Epoch 3/3
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 182.8669
# {'loss': [146.43931579589844, 186.28041076660156, 182.86692810058594]}
